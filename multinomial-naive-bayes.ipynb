# %% [markdown]
# Importing the `train`, `test` and `test_labels` csv file.
# ---
#
# `trainData` includes a column of text and six other columns of labels with values of 0s and 1s indicating whether the text belongs to those labels.
#
# ---
# `testData` includes only a single column of text.
#
# ---
# `testLabels`includes *1s and 0s* corresponding to each label, indicating whether the text belongs to that label or not.

# %%
import pandas as pd

trainData = pd.read_csv("./train.csv")

testData = pd.read_csv("./test.csv")

testLabels = pd.read_csv("./test_labels.csv")

# Converting pds to np arrays
trainData = trainData.values
ogTestData = testData.values
testData = testData.values
testLabels = testLabels.values

trainData = trainData[:, 1:]
testData = testData[:, 1:]
testLabels = testLabels[:, 1:]

print("Train Data:")
print(trainData.shape)
print("\n")
print("Test Data:")
print(testData.shape)
print("\n")
print("Test Labels:")
print(testLabels.shape)
# Out:
# Train Data:
# (159571, 7)
#
#
# Test Data:
# (153164, 1)
#
#
# Test Labels:
# (153164, 6)

# %% [markdown]
# Downloading `stopwords` and importing my data cleaning functions to clean the tweets included.
# ---

# %%
import re
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

from nltk.corpus import stopwords
stopwords = stopwords.words('english')

def lowercase(txt):
    return txt.lower()

def remove_punctuation(txt):
    newTxt = re.compile(r'[^\w\s]').sub('', txt)
    return newTxt

def remove_stopwords(txt):
    newTxt = []
    words = txt.split()
    for word in words:
        if word not in stopwords:
            newTxt.append(word)
    return str(" ".join(newTxt))

def remove_numbers(txt):
    newTxt = re.compile(r'\d+').sub('', txt)
    return newTxt

def remove_url(txt):
    newTxt = re.compile(r'https?://\S+|www\.\S+').sub('', txt)
    return newTxt
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mshum\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Cleaning the data.
# ---
# `trainData` and `testData` get repopulated with the cleaned sentences, row by row.

# %%
newTrainData = []
newTestData = []
for row in range(trainData.shape[0]):
    temp = trainData[row][0]
    temp = lowercase(temp)
    temp = remove_punctuation(temp)
    temp = remove_stopwords(temp)
    temp = remove_numbers(temp)
    temp = remove_url(temp)
    newTrainData.append(temp)
    # trainData[row][0] = temp

temp = ""
for row in range(testData.shape[0]):
    temp = testData[row][0]
    temp = lowercase(temp)
    temp = remove_punctuation(temp)
    temp = remove_stopwords(temp)
    temp = remove_numbers(temp)
    temp = remove_url(temp)
    # testData[row][0] = temp
    newTestData.append(temp)

trainData[:, 0] = newTrainData
testData[:, 0] = newTestData

# %% [markdown]
# Removing certain row data from `testData` and the corresponding `testLabels` *as they consist of -1s and those text's were not being test*, and it's invalid `testData` which will negatively affect our accuracy and results.

# %%
import numpy as np
rows_to_keep = np.all(testLabels != -1, axis=1)

testLabels = testLabels[rows_to_keep]
testData = testData[rows_to_keep]

testData = testData.flatten()

# %% [markdown]
# Extracting `features` and `labels` from `trainData`.

# %%
features = trainData[:, 0]
labels = trainData[:, 1:]

# %% [markdown]
# Firstly I convert the text into numbers using `CountVectorizer`, for both `testData` and `trainData`.
#
# ---
#
# After that I extract individual labels for each classification in column vectors.
# In the end getting six column vectors of train and test Labels for each label i.e `toxic, severe_toxic, obscene, threat, insult, identity_hate`.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import MultiLabelBinarizer
import numpy as np

# Vectorize the text data using CountVectorizer
vectorizer = CountVectorizer()
X_train_vectorized = vectorizer.fit_transform(features)
X_test_vectorized = vectorizer.transform(testData.tolist())

# Labels = toxic, severe_toxic, obscene, threat, insult, identity_hate

yTrainToxic = labels[: , 0].astype(np.float64)
yTestToxic = testLabels[: , 0].astype(np.float64)

yTrainSevereToxic = labels[: , 1].astype(np.float64)
yTestSevereToxic = testLabels[: , 1].astype(np.float64)

yTrainObscene = labels[: , 2].astype(np.float64)
yTestObscene = testLabels[: , 2].astype(np.float64)

yTrainThreat = labels[: , 3].astype(np.float64)
yTestThreat = testLabels[: , 3].astype(np.float64)

yTrainInsult = labels[: , 4].astype(np.float64)
yTestInsult = testLabels[: , 4].astype(np.float64)

yTrainIHate = labels[: , 5].astype(np.float64)
yTestIHate = testLabels[: , 5].astype(np.float64)

# %% [markdown]
# Now I run the Multinomial Naive Bayes classifier for each label.
# ---
# 1. Creating a separate instance of `MultinomialNB()` for each label.
# 2. Fitting it on the vectorized train data and the column vector of the specific train label class, i.e `toxic, severe_toxic, obscene, threat, insult, identity_hate`.
# 3. Getting the instance to predict the vectorized test Data.
# 4. Using the column vector of the specific test label class, and getting the accuracy.

# %%
toxic_classifier = MultinomialNB()

toxic_classifier.fit(X_train_vectorized, yTrainToxic)

y_test_toxic = toxic_classifier.predict(X_test_vectorized)

accuracy = accuracy_score(yTestToxic, y_test_toxic)

print("Toxic Test Accuracy:", accuracy)
# Out:
# Toxic Test Accuracy: 0.9209884647847698

# %%
severeToxic_classifier = MultinomialNB()

severeToxic_classifier.fit(X_train_vectorized, yTrainSevereToxic)

y_test_sToxic = severeToxic_classifier.predict(X_test_vectorized)

accuracy = accuracy_score(yTestSevereToxic, y_test_sToxic)

print("Severe Toxic Test Accuracy:", accuracy)
# Out:
# Severe Toxic Test Accuracy: 0.9820407014911375

# %%
obscene_classifier = MultinomialNB()

obscene_classifier.fit(X_train_vectorized, yTrainObscene)

y_test_obscene = obscene_classifier.predict(X_test_vectorized)

accuracy = accuracy_score(yTestObscene, y_test_obscene)

print("Obscene Test Accuracy:", accuracy)
# Out:
# Obscene Test Accuracy: 0.9488730501109757

# %%
threat_classifier = MultinomialNB()

threat_classifier.fit(X_train_vectorized, yTrainThreat)

y_test_threat = threat_classifier.predict(X_test_vectorized)

accuracy = accuracy_score(yTestThreat, y_test_threat)

print("Threat Validation Accuracy:", accuracy)
# Out:
# Threat Validation Accuracy: 0.9898871487073682

# %%
insult_classifier = MultinomialNB()
insult_classifier.fit(X_train_vectorized, yTrainInsult)

y_test_insult = insult_classifier.predict(X_test_vectorized)

accuracy = accuracy_score(yTestInsult, y_test_insult)

print("Insult Test Accuracy:", accuracy)
# Out:
# Insult Test Accuracy: 0.9462158867110569

# %%
hate_classifier = MultinomialNB()
hate_classifier.fit(X_train_vectorized, yTrainIHate)

y_test_hate = hate_classifier.predict(X_test_vectorized)

accuracy = accuracy_score(yTestIHate, y_test_hate)

print("Hate Test Accuracy:", accuracy)
# Out:
# Hate Test Accuracy: 0.9806339679264747

# %% [markdown]
# Combining the predicted values of six columns to get the predicted labels across each class in a single np array.
# ---

# %%
import numpy as np
predictedValues = np.zeros((X_test_vectorized.shape[0], 6))
predictedValues[:, 0] = y_test_toxic
predictedValues[:, 1] = y_test_sToxic
predictedValues[:, 2] = y_test_obscene
predictedValues[:, 3] = y_test_threat
predictedValues[:, 4] = y_test_insult
predictedValues[:, 5] = y_test_hate
# predictedValues = np.concatenate((y_test_toxic, y_test_sToxic, y_test_obscene, y_test_threat, y_test_insult, y_test_hate), axis=1)

# %% [markdown]
# Formatting labels so that the corresponding label is outputted instead of *1s and 0s* for both the `predictedLabels` and the true labels i.e `testLabels`.

# %%
label_names = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']

testLabelsOutput = []
predictedValuesOutput = []

for row in range(testLabels.shape[0]):
    label = ""
    for x in range(6):
        if testLabels[row][x] == 1:
            add = label_names[x] + " "
            label += add
    if (label == ""):
        testLabelsOutput.append("")
    else:
        testLabelsOutput.append(label)


for row in range(predictedValues.shape[0]):
    label = ""
    for x in range(6):
        if predictedValues[row][x] == 1:
            add = label_names[x] + " "
            label += add
    if (label == ""):
        predictedValuesOutput.append("")
    else:
        predictedValuesOutput.append(label)

# %% [markdown]
# Outputting the `testData`, its `trueLabels` and the `predictedLabels` which we got after predicting the `testData` against each class separately and then combining all the `predictedLabels` into a single matrix.
# ---
# This way we get a clear comparison between the `trueLabels` of the text and what our model was able to predict.

# %%
for row in range(testData.shape[0]):
    if (testLabelsOutput[row] != "" and predictedValuesOutput[row] != ""):
        print("Text: ", testData[row])
        print("True Labels: ", testLabelsOutput[row])
        print("Naive Bayes Predicted Labels: ", predictedValuesOutput[row])
        print("\n")
# Out:
# Text:  dj robinson gay hell sucks dick much
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  fuck antisemitic cunt
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  arrogant self serving immature idiot get right
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic insult
#
#
# Text:  hate america going bomb shit cities quezas rain
# True Labels:  toxic obscene threat
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  bold textyou suck u suck hannah montana
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  ghay ass fucker
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  simple stupid
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  random deletion deleted xanax bars fuck mah nigga fuck wit em good links section
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  drunk made gibson say really believes little freak nazi like father hope dies lung cancer soon
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  hey shithead stop vandilizing articles
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  warning first warning stop gay raped ass indefinitely without notice
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  feel like man instead idiot
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  maybe one days cool random quote way like fucking breeders dont fuck sex
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  ya still fuk u
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  casualt fucked mum liked ies
# True Labels:  toxic severe_toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  xbox  sukcs big bumm likes ass
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  karl tearle mop haired twat
# True Labels:  toxic insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  give blowjobs hot women alderley edge cheshire
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  think delete whole fuckin wikipedia
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  willeys u male willey u likley gay lol
# True Labels:  toxic identity_hate
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  hate eagles  since made comment every action undertake somebody fucking ass im thinking trip ani would productive thoughts
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  cause shes devil evil mind penis materialscientists birth place
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  cite policies wasting fucking time cite policy ill strike bastards better good fucking idea complaint say youre wasting goddamn time opinions worthless matters policies guidelines sources dont give pile steaming dogshit manners sounding nonsense bullshit understanding community mores whole fuck lot ruder opinion jesus christ stop politetrolling learn fucking rules wikipedias rulessimplecomplex
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  go court shit cause judge look like motherfucker put ass boat made nigga outro mamma rag nigga durag nigga ballistics nigga im urethas nigga nigga
# True Labels:  toxic severe_toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult identity_hate
#
#
# Text:  hey asshole quit removing facts article motherfucker
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  kevin bravo faggot
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic insult
#
#
# Text:  users like make wikipedia shithole youre fucker get life could vandalize want dare earse agoian change name fuckboti kill cut corpse hell ill chop yo mama yo daddy yo baldheaded granny yo mama fat need map get around fat relations shamu come fucker whats worst users like make wikipedia shithole youre fucker get life could vandalize want dare earse agoian change name fuckboti kill cut corpse hell ill chop yo mama yo daddy yo baldheaded granny yo mama fat need map get around fat relations shamu come fucker whats worst doit users like make wikipedia shithole youre fucker get life could vandalize want dare earse agoian change name fuckboti kill cut corpse hell ill chop yo mama yo daddy yo baldheaded granny yo mama fat need map get around fat relations shamu come fucker whats worst doit users like make wikipedia shithole youre fucker get life could vandalize want dare earse agoian change name fuckboti kill cut corpse hell ill chop yo mama yo daddy yo baldheaded granny yo mama fat need map get around fat relations shamu come fucker whats worst doit users like make wikipedia shithole youre fucker get life could vandalize want dare earse agoian change name fuckboti kill cut corpse hell ill chop yo mama yo daddy yo baldheaded granny yo mama fat need map get around fat relations shamu come fucker whats worst doit users like make wikipedia shithole youre fucker get life could vandalize want dare earse agoian change name fuckboti kill cut corpse hell ill chop yo mama yo daddy yo baldheaded granny yo mama fat need map get around fat relations shamu come fucker whats worst doit users like make wikipedia shithole youre fucker get life could vandalize want dare earse agoian change name fuckboti kill cut corpse hell ill chop yo mama yo daddy yo baldheaded granny yo mama fat need map get around fat relations shamu come fucker whats worst doit users like make wikipedia shithole youre fucker get life could vandalize want dare earse agoian change name fuckboti kill cut corpse hell ill chop yo mama yo daddy yo baldheaded granny yo mama fat need map get around fat relations shamu come fucker whats worst doit users like make wikipedia shithole youre fucker get life could vandalize want dare earse agoian change name fuckboti kill cut corpse hell ill chop yo mama yo daddy yo baldheaded granny yo mama fat need map get around fat relations shamu come fucker whats worst doit users like make wikipedia shithole youre fucker get life could vandalize want dare earse agoian change name fuckboti kill cut corpse hell ill chop yo mama yo daddy yo baldheaded granny yo mama fat need map get around fat relations shamu come fucker whats worst doit users like make wikipedia shithole youre fucker get life could vandalize want dare earse agoian change name fuckboti kill cut corpse hell ill chop yo mama yo daddy yo baldheaded granny yo mama fat need map get around fat relations shamu come fucker whats worst doit users like make wikipedia shithole youre
# True Labels:  toxic obscene threat insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  whole doormatt joke funky fuck wrote
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  anoymous bunch cunts scared show selves real world
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  wikipedia dickshits like u retarded wikpedia gay
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic insult
#
#
# Text:  im gay whack ogrish rape
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  wat heck hell wrong next time vandalize page im going fayetteville arkansas beating crap
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  cut bitch
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  troll think jimbo wales idiot wikipedia rubbish
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  omg text site u edit lolololol wat thinkone night lead toyeah shove cock inup vigina says ruthiemackenzie someone edited aka know shouldnt typing stuff like wiki really fun like bitch makenzie really mother   year old daughter slut sexuall intercoarse  omg omg omg fuck going getting preety late think going  bed thank u goooooood night think husband comiing gg sees typing aaaaaaaaaaaaaaaaaaaaaaaaaaahhhhhhhhhhhhhhhhhhhhhhhhhhhhh wouldnt want  anyway nothing  darn actress btw self obseesssed whore yeahhhhhhhhhh baby kids dont sex till married cause sex  turned dont even try condom unlike mackenzie roman virgin acturely beutiful thingwell sexim acturely married  children u probably think bull anyway nows might man s lol question  belive  belive btw exact personthat someone edited aka
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  foolish nonsense never something stretched point communicating friends friends people side earth quite pathetic actually calton inconsiderable selfish beast
# True Labels:  toxic insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  dr marmilade youre bastard proassad wedgeassad go die
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  fuck like angelique carrington tamara harringtonfuck asshole
# True Labels:  toxic severe_toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  r guy mother fucker
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:   fuck butt nigger
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult identity_hate
#
#
# Text:  ryan boe queer truth hes big ol gay bag
# True Labels:  toxic insult identity_hate
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  still annoyed blockig dmacks idiot
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  threatening block reason fucking bitch
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  fuck islam fuck saud arabia
# True Labels:  toxic severe_toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  una mierdatu puta madre
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  wow wnt damn kookie nigga
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult identity_hate
#
#
# Text:  ruined moron ruined page trash unusable revert immeadeatly
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic insult
#
#
# Text:  fuck u mother fucker
# True Labels:  toxic severe_toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  dudeget fucking clue goth dressing black shitu hail satian sort shit emo emo sit room day staring ceiling wondering anyone would really care fell killing instantlyi knowemo self harm cutting etcwanting diejust like
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  u dum fukers mrharris suks cocks likes anal
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  jerk write huge jerk isnt
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  luna santin fucker likes gay niggers gay niggerlover
# True Labels:  toxic severe_toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult identity_hate
#
#
# Text:  jerk cahin hard
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  arent banned yet homophobic mexican arsehole
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  im bit grumpy fuck
# True Labels:  obscene
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  maybe youre ashamed enjoying looking picture dont want cp ashamed pedo
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  nigga dont care fuck
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  jeez ed seem like fucking shitty douchebag
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck fuck
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult identity_hate
#
#
# Text:  azerbaijanis proud ramil safarov opportunity circumstances would kill bastard mother fucker armenians bitches soldiers insulting azerbaijani flag bastard gurgen lay hell mother fucker fuck soul whore mother assholes fuck armenian fascists natinoalists
# True Labels:  toxic obscene threat insult identity_hate
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  yeah right dude im fucking ill give links look prove real damn real kurt angle
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  beat hell stop getting rid cool junk aight homie know get along must fight
# True Labels:  identity_hate
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  suck dick assholes
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  warthog like halo  fucking retard  july  utc
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  ps deleted talk page idiot j delanoy blocked wpdeny another greasy pimplefaced adolescent spends way much time encyclopedia dramatica isnt intelligent enough really contribute
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  bitch edits
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  ok true hello means stuiped stpido knw boobs hebrew zizim
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  alternatively maintain limericks meter poor little bastard dead
# True Labels:  toxic insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  changes duarte true wikipedia sucks
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  sup peeps japan sucks hola mexico senioritas suuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuucccccccccccccccccccccccccccccccccckkkkkkkkkkkkkkk
# True Labels:  toxic insult
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  slutty whore sluty whore
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult identity_hate
#
#
# Text:  shit country
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  soooooo dick think youre dick tom cruise whoever locked page page able edit wish
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  joshua rocks joshua rocksyou suck suck rule suck ha ha ha
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  um wtf stay fuck userpage stop putting ur shitty opinions one cares
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  firestar power hungry arse
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  altho game shit players terrible riot game producers care money suspend disconnect game people still play brainwashed little fucks
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  well lazy arrogance many fucking times people say hey pal coi issue actually fucking stop read got attention power said would blocked didnt start responding responded weak applause showed zero evidence giving fuck coi much less read much less caring integrity wp done fucking done
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  ill kill piss mouth anyone supports soviet scum furthermore support murder public
# True Labels:  toxic obscene threat insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  im trying really difficult insistance dragging nazi bullshit time
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  filthy vandal see one know ever buys stupid megadry site preceding unsigned comment added
# True Labels:  toxic insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  hey asshole show respect
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  oh hey fuckface go day buddy
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  sex plushies
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  oh also take  responsibility worthless piece shit lynched killed
# True Labels:  toxic obscene threat insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  youre idiot
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic insult
#
#
# Text:  hi giggy puny shonen post pile new feedback zilla famous gumption helpfulness sweet temper atomic deathray sex weenie shonen famous one thing meanness
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  threat idiot vandal gorgonzolla
# True Labels:  toxic insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  dunb fuck idiots going learn dont give fuck dumb fucking policies suck dick continue vandalize user pages chicken shit pussy queers quit fucking legitimate edits skyline chili middletown indiana
# True Labels:  toxic severe_toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  oh jesus fucking christ grow quit ur bellyaching wiki gofixit
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boob boo ...
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene threat insult identity_hate
#
#
# Text:  theres rulego fuck yourselfmamu ti jebem
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  monkey b utt scrfatcher monkey butt scratch monkey butt scratcher
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  pictures penis sizes shouldnt add picture average penis short penis long penis like one
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  thanks laugh userreported manually removing evilblood already blocked suck bot
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  wikipedia full highly biased ultraliberal homosexual tranny freaks hi someday go us ill marry course came first yeah ryan bruce whatever name consider accepting hating others ill shoot head way im perfectly normal aka straight concept people hate gays secretly gay lie told gays gay supporters simply dislike gays extremely disgusting stop calling bruce jenner dumbasses  population california including dislikes fags
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  generals bam doog sucking video generals sucking dick wacking pos chest lets post pests wack aight
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  horn penis virgin rape retards stop pretending play professor
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  stop changing e article true e transcendental dont u go fuck leave paragraph alone
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  poop psychological word crap
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  continue warn become like stupid retarded
# True Labels:  toxic insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  fanbase consists niggers white trash big ben likes rape chicks
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  fuck slag
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  u wot u wot u wot u wot u wot u wot u wot u wot reverted need douchebag
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult identity_hate
#
#
# Text:  somewhere retarded backstory fire bh go fk fk
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  wow youre funny motherfucker know dont waste talent goddamn radio seriously though vandalizing wikipedia kicks need hobby read book go outside jerk something productive
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  wikipedia sucks automatically delete anything connected james rolfe tried warn world mr buckets evil dangerous nature sucking balls
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  fuck admins fuck stupid copyvio fair use one cares community consensus started deleting images wikipedia turned communism admins bossing everyone else around asinine cant user page leaving
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  stop removing mine fuckface
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  shit hate country
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  guys bunch assholes
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  fk spanish idiot rule britannia
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  dumb could go suck dicktalk
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  unblockfucking unblock ill fucking ban banhammer bitch
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  rev fuck buddy mind ur damn business good one
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  one slow persistent motherfucker read
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  even every sexual person fantasizes masturbating males many females think libidinous asexuals masturbate reason would scratch itchy
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  bill dear sir gay stay dans bum
# True Labels:  toxic insult identity_hate
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  mom makes living sucking penises dad also farmyard donkey
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  anonymous hackers lied stupid hoes dont know nothing
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  boys boys jerks dont let get u
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  eat dick fag
# True Labels:  toxic severe_toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  utc fucking hate hole suck ass offence fans parden language honestly think courtney love jelous kurt kind way think strong opinion ok killed kurt   january
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  diabeetus go die diabeetus already
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  haha vandalism idiot
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic insult
#
#
# Text:  malleus fatuorum youre quite condescending asshole changes diaper seems due
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitonly stupid niggers like antandrus likes shitv
# True Labels:  toxic severe_toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic obscene insult identity_hate
#
#
# Text:  fuck osama bin laden afghanistani terrorist cunts
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  wow ur idiot dont something stupid mate shut hell u dont like people say
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  admins must die prepare death banno
# True Labels:  toxic threat
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  kiss asshole bitchezzzzzzzzzzzzzzzz
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  fuck ass hole sek
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  juicy butt holes
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  fuck assholes perverts
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  big hairy ape like mamith
# True Labels:  toxic insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal anal anal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal anal anal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal anal anal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal anal anal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal anal anal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal anal analanal ana ...
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  adam gontier adam gointer ass wipe
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  paging dr faggot please block sock although like many wikipedia editors busy banging hot chicks fri night
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  people incredibly stupid
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  lakers suck massive ass holes dude gay hell mom sucks big ass dick ever umeet u ill make u suck motha fuckin dick dont forget fuckin long xxl shorts
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  sixty years later  kode got ass smokin shit hell mean
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  madblast asshole
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  axking dirty werks p e
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  thats nonsense fat animals cute fuzzy become fat squishy soft fat humans gross mostly hairless fat makes smooth ball grotesque flab
# True Labels:  toxic insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  fucking cu blocked faggot
# True Labels:  toxic severe_toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  know youre open minded im stupid jerk
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  listen smartass fuck motherfucking douchebag bet youre member order demolay like lucifer adolf eichmann
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  every one reads wiil die lol im sexy hot huge boobies call
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  gonna make yourape peopleget life stop talking strawberries go eat cherries something word
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  hey youre fag wish werent fag go fuck
# True Labels:  toxic severe_toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  ass dick pussy like dick suck name batista
# True Labels:  toxic severe_toxic obscene
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  best gay porn httpgayporncom
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  going rip tiny balls decapitate
# True Labels:  toxic obscene threat
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  shawn dickhead fucking faggot assholoe small tits big ass ass dick cuz hes faggit gay sucks dick hallway school cuz hes gayyyyyyyyy
# True Labels:  toxic severe_toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult identity_hate
#
#
# Text:  hay fuck head r u kind wikipedia cop yur fucking nazi pathetic get fucking life yur pathetic u try get power ppl ont internet makes u happy aobut ur life thats sad wikipedia supposed freedom information u cant wrap ur facist little mind around u
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  agree rob halford singer jp freakin bald
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  penis
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  vandalism dont really care wikipedia italicized sick fucking death people accusing disagree vandalism idea youre jerk thats certainly image head
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  gay faggot liked
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  wtf f bastards
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  sorry asshole insane delete article like
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  nick schweikhart nick spends day every day playing stupid circle game
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  go fuck urself u dirty cunt write anything want dirty peodo mahamed terrorist followers thought wiki facts remove facts u prick
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  fine fuck im sick cyberbullied look like shit
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  youre fucking idiot
# True Labels:  toxic severe_toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  lol u ppl hav something wrongjust live fuckers stfu
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  really really suck terrible admin really bad person total douche
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic insult
#
#
# Text:  disgusting shameful loathing wiki article love bears image roman eros statue corresponding image hate isnt time banned hollywood little mickeys round tits
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  oh yes leave fucking sub heading go fuck selves article joke
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  penis length know penis length cause said guess pornstars always tell truth especially topic everyones cm delete post whrer got
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  black people deserve die
# True Labels:  toxic severe_toxic threat identity_hate
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  hey dumb ass moron whoever said act jsut die cause hiliary great actress hating
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  fuck fuck
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  urg guy damn annoying man
# True Labels:  toxic insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  knew dirty jew
# True Labels:  toxic insult identity_hate
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  arguing conpiracy theorist like trying toilet train badger annoys badger get covered crap
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  trouted whack trouted bitch trying ban
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  senior drill instructor lost home katrina fuck bitch
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  fucking cock balls im drunk lord
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  cut testicles force eat bet youll like sick bastard cut testicles force eat bet youll like sick bastard
# True Labels:  toxic obscene threat insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  sure like hairy balls
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cunt cuntv
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult identity_hate
#
#
# Text:  starfish gay
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  yeah really admitted matter passport went land broke rules must pay price guy piece shit dont want back either fuck ron smith
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  dear cluebot ng suck far better
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  maclnnis extremely gay fat sweaty men
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  linuxbeak stop acting like cunt go cyber taxman irc join enwikipediafag theyre receptive kind
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  fuck asshole dont stop insulting harry potter motherfucking bitchasshole fuck harry potter fuck harry potter fans die motherfucker die
# True Labels:  toxic severe_toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  wow dumb could theyre everywhere stupid person
# True Labels:  toxic obscene insult
# ...
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene threat insult identity_hate
#
#
# Text:  bestiality linked article linked another recurring theme includes zoophiliasexual activity animals also mentioned stan masturbated dog mrgarrison sex pig sexual orientation animals like stans dog gay recurring theme
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  fuck mong cunt face wanker
# True Labels:  toxic severe_toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  stop fucking page asshat
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  fucking thing right fucking ridiculous
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  nigga deleted shit bitch nigga
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult identity_hate
#
#
# Text:  dick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzdick cheese zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz ...
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  obama call political opponent cancer bitch laugh loud someone else
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  napleon died suucking muk dik haveing mch butt sex
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult identity_hate
#
#
# Text:  vandalisers like  dolla hoes bitch bitch bitch bitch bitch
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult identity_hate
#
#
# Text:  slut hope get breast cancer vile little piece pelican shit slutty teenage bitch
# True Labels:  toxic severe_toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  hi frank thing little gay twat
# True Labels:  toxic insult identity_hate
# Naive Bayes Predicted Labels:  toxic insult
#
#
# Text:  one thing known qwestthey suck balls thousand men
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  zangief gay hey lindsay dude fucking homosexual go glory hole places deal stop messing around best character teh capcom universe zangief gay fuck pussy fairy go sing chorus something zangief rules
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  fuck valverde piece fucking shit
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult identity_hate
#
#
# Text:  ah error thought wp collegial spot apparently ive growed several times sadly fucking wp elimination childish churlish reveling ones dont give crap except stuff attitude look said fuck iz growed wonder wp withering vine sad puerile display children next youll stomping feet sandbox
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  fck sht head
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  one wants children seeing explicit photo woman eating butthole sucking penis thats friggin disgusting
# True Labels:  toxic severe_toxic obscene
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  constructive httpsenwikipediaorgwikidestruction fuck death real ideals cancer
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  bold textfuck ass hole yah fuck fucking pice fucking shit fuck fuck fuck war want well war get fucking bastaerd fucking bastered fuck fuck
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  ur dumb jerk blocked gonna move switserland get car fill water ruining upholstery sell use money computer call jerk love england good jerks like also buy mouse feed cheese selll buy switserland buy  computers ii call laywer al yankovic come yopur house night eat food put like  cats house put tea table put label says breakfest alein come eat house able block make look like idiot gqfbhvrycgsaafvsaydgbchgswdhfgadshgcfhsgahsyghfdghsfgbdsgchfgdshbcgfashdcgfhsdagchgfhasdgchfdghfdsaghcdg hdgfhasdgfh hd vgfgehycfb tv suck
# True Labels:  toxic severe_toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  hey grow knock ridiculous rightwing rhetoric get life pathetic loser
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  wtf f put userbox saying faggot dont support homosexuality
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  got fucking kidding cant believe mentioning woman said would commit suicide weeks said alex jones show quote times deborah told someone disreputable thats fucking stupid fuck wikipedia
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  crboyer misserable fuck constructive enough
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  whats negativity dumbass mother fuckers insisting artists release failed
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  rape sick tired movies using rape horror entertainment last one disgusting way mutant breast fed fucking sick
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  shes little self obssessed self righteous bitch thats think
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  shit bad word shit swearword examples shit used cow shit shit hurt shit broken shit head poo head
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  sperre blacklist hallo wenn mir die einsicht meine bnutzertätigkeit verweigert wird kann mich wikipedia arsch lecken refused get regular insight edits wikipedia kiss ass
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  vandalism destroyer sucks balls
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  u suck u suck
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult
#
#
# Text:  wow keep blocking dun like ur fat ugly oh ya u going block dumb thought suck go screw urself preceding unsigned comment added
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  b stylefontsizepxcalvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger calvin fucking nigger
# True Labels:  toxic severe_toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic severe_toxic obscene insult identity_hate
#
#
# Text:  meet one day stab death prepared say goodbye life fucking homophobic gay prick prepare die tbhotch along family help please block ip revdel contributions
# True Labels:  toxic severe_toxic obscene threat insult identity_hate
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  shut
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  oh thats airportthats theyre hiding wmds know townthey arent fucking around rumor theyre going invade poland next september
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  retard business strike means coin minted circulation collectors maybe shut mouth stuff dont know anything dummy
# True Labels:  toxic insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  career aspiration become christian preacher faggot
# True Labels:  toxic obscene insult identity_hate
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  roby wayne fuck
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  adrian hes gay
# True Labels:  toxic insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  anyone else find fucking hilarious know lmfao
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic obscene
#
#
# Text:  miami high next target eric david harris idol dont give fucking shit fuck cunts think lets see fucking worthless scums get kicked ground everyday trying live youre already fucked life top shit get fucking cunts teachers laughing fucking kill everyone school  pictures ocd downloaded anarchist cookbook dont care die fuck im going kill every mother fucking imbreed cunt miami state high school even someone try stop dare comon fucking cops kill everyone  april made pipe bombs ect ect yeah yeah yeah try stop piggies _ eric
# True Labels:  toxic obscene threat insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  fucking right
# True Labels:  toxic obscene
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  baylor kids like kill
# True Labels:  toxic
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  dude bitches sit police gay website cant isnt even viable information people like guys thanks making world better place conche tu madre
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic
#
#
# Text:  tom ya soooo awesome lololololololololoololololol soooooo wat people u stupid never guesss dr zoid berg lol c man
# True Labels:  toxic insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  sorry dickhead cannae help douche bag dumbass bitch boy please would like change lifeless loser
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
#
#
# Text:  nigel crazy idiot
# True Labels:  toxic insult
# Naive Bayes Predicted Labels:  toxic insult
#
#
# Text:  mel gibson nazi bitch makes shitty movies much buttsex asshole big enough considered country
# True Labels:  toxic obscene insult
# Naive Bayes Predicted Labels:  toxic obscene insult
